# %%
suppressPackageStartupMessages(library(ggplot2))
suppressPackageStartupMessages(library(openxlsx))
suppressPackageStartupMessages(library(VennDiagram))
suppressPackageStartupMessages(library(RColorBrewer))
suppressPackageStartupMessages(library(igraph))
suppressPackageStartupMessages(library(kimono))
suppressPackageStartupMessages(library(ggnet))
suppressPackageStartupMessages(library(orthologsBioMART))
suppressPackageStartupMessages(library(tidyverse))
suppressPackageStartupMessages(library(dplyr))
suppressPackageStartupMessages(library(forcats))

# %%
network = as.data.frame(read.xlsx("../Tables/S7_GRtrio-Network_Gene.xlsx"))
dim(network)
head(network)
# Out:
# [1] 849  11
#   Target          Predictor  Mean                SD
# 1 ENSG00000000938 cg05783223 0.132838956137275   0.00521814224207415
# 2 ENSG00000001461 cg25725023 -0.0680779339709776 0.00692557185950274
# 3 ENSG00000002919 cg11356791 0.322202791069016   0.0114688343543777
# 4 ENSG00000004700 rs8176263  0.0980964933581561  0.0196522212580658
# 5 ENSG00000004700 rs8176242  -0.0465728594734857 0.00799586865045767
# 6 ENSG00000004700 rs8176220  0.0715240378297468  0.00965051285934614
#   Mean_RSQ          SD_RSQ             Mean_MSE          SD_MSE
# 1 0.381973682918172 0.0204985025641654 0.396092897583553 0.0130262945913083
# 2 0.170010489976676 0.0261142738490575 0.678562067911749 0.0205713300548499
# 3 0.239896208686591 0.0238938319904384 0.598404653722696 0.0167065567615699
# 4 0.140777508697034 0.028805469975622  0.661648664999057 0.0311428351450754
# 5 0.140777508697034 0.028805469975622  0.661648664999057 0.0311428351450754
# 6 0.140777508697034 0.028805469975622  0.661648664999057 0.0311428351450754
#   Predictor_layer Target_layer Gene_symbol
# 1 CpG             Gene         FGR
# 2 CpG             Gene         NIPAL3
# 3 CpG             Gene         SNX11
# 4 SNP             Gene         RECQL
# 5 SNP             Gene         RECQL
# 6 SNP             Gene         RECQL

# %% [markdown]
# ## Panel A - GR-trio network

# %%
# create network
ig_network = to_igraph(network, directed=TRUE) 
#ig_network %>% plot_kimono
node_labels = V(ig_network)$name

# extract top layer
gene_part = as.character(sapply(node_labels, function(x) gsub("^(.*?)__.*$", "\\1", x)))

# create color vec
node_color = ifelse(gene_part == "Gene", "blue",
                                   ifelse(gene_part == "CpG", "green",
                                          ifelse(gene_part == "SNP", "yellow", "red")))

ggnet2(ig_network, node.size = 1, node.color = node_color, edge.size = 0.5,
       edge.color = "grey",size = "degree")
# Out:
# Warning message in is.null(x) || is.na(x):
# “'length(x) = 1078 > 1' in coercion to 'logical(1)'”
# Warning message in is.null(x) || is.na(x) || is.infinite(x):
# “'length(x) = 1078 > 1' in coercion to 'logical(1)'”
# Warning message in is.null(x) || is.na(x) || is.infinite(x) || is.nan(x):
# “'length(x) = 1078 > 1' in coercion to 'logical(1)'”
# plot without title

# %% [markdown]
# ## Panel B - Barplot

# %%
network.df = as.data.frame(network)
network.df$relation = ""
network.df[ network.df$predictor_layer=="CpG" & network.df$target_layer=="Gene",]$relation = "methyl_expr/eQTM"
network.df[ network.df$predictor_layer=="SNP" & network.df$target_layer=="Gene",]$relation = "snp_expr/eQTL"

ggplot(network.df, aes(relation, fill=relation)) + geom_bar(stat = "count") +
 geom_text(stat = "count",  aes(label = ..count..), vjust = 1.5,
           position = position_dodge(0.9), size = 3.5) + theme_classic()
# Out:
# plot without title

# %% [markdown]
# ## Panel C - GO pathways

# %%
fuma = read.delim("data/Fuma_GS.txt")
fuma.go = fuma[ fuma$Category == "GO_bp",]

ggplot(data = fuma.go, aes(x=GeneSet, y=-log10(adjP))) +
  geom_bar(position="dodge", stat="identity") + theme_minimal() +coord_flip()+xlab("")
# Out:
# plot without title

# %% [markdown]
# ## Panel D-E - Venn diagram  and Bar plot (DiffBrainNet)

# %%
diffbrain = read.csv("data/DiffBrainNet_DEGenes.csv")
length(unique(diffbrain$Ensembl_ID))
# Out:
# [1] 2092

# %%
# lift to human genes
diffbrain_h=findOrthologsMmHs(from_filters = "ensembl_gene_id",
                  from_values = diffbrain$Ensembl_ID,
                  to_attributes = "hgnc_symbol")
dim(diffbrain_h)
length(unique(diffbrain_h$human_ensembl_gene_id))
# Out:
# [1] 2026    3
# [1] 2015

# %%
trio =read.delim("data/GRtrio_genes.txt", head=F)
length(unique(trio$V1))
# Out:
# [1] 613

# %%
#shared background genes
bg=read.delim("data/GRtrio_bg.txt", head=F)

a= intersect(bg$V1 , trio$V1) 
b= intersect(bg$V1 , diffbrain_h$hgnc_symbol) 

set_colors <- c("blue", "gray")
sets <- list(GRtrio_genes = a, GRDEGenes = b)
venn_bcc=venn.diagram(sets, filename = NULL,scaled = TRUE, scaling.area = TRUE, fill = set_colors, alpha = 0.5, lwd = 2)
grid.newpage()
grid.draw(venn_bcc)
# Out:
# plot without title

# %%
overlap = diffbrain[ diffbrain$Ensembl_ID %in% (diffbrain_h[ diffbrain_h$hgnc_symbol %in% 
                                                  trio$V1,]$mouse_ensembl_gene_id),]
dim(overlap)
# Out:
# [1] 100   4
#     X   Gene_Symbol Ensembl_ID         region
# 30   30 Ifrd1       ENSMUSG00000001627 AMY, CER, dDG, dCA1, PFC, PVN, vDG, vCA1
# 37   37 Nfix        ENSMUSG00000001911 CER, dDG, dCA1, PFC, vDG, vCA1
# 54   54 Nab1        ENSMUSG00000002881 PFC
# 70   70 Nfat5       ENSMUSG00000003847 CER, PFC, vDG
# 85   85 Arid3b      ENSMUSG00000004661 PFC
# 113 113 Cbfa2t3     ENSMUSG00000006362 dDG, dCA1, PFC, vDG, vCA1

# %%
# Split the "region" column by commas
region_list = strsplit(overlap$region, ",")

# Flatten the list of regions
all_regions = unlist(region_list)

# Remove spaces in each entry
all_regions = gsub(" ", "", all_regions )

# Count the occurrence of each region
region_counts = table(all_regions)

# Sort the regions by count in descending order
region_counts = sort(region_counts, decreasing = TRUE)

# Create a bar plot of region counts
x = data.frame(count = region_counts)
ggplot(x,
       aes(x =  count.all_regions , y = count.Freq)) +
  geom_bar(stat = "identity" ) +
  labs(x = "Region", y = "Count") +
  ggtitle("Gene Counts by Region") +
   theme_classic() + coord_flip()
# Out:
# plot without title

# %% [markdown]
# ## Panel F Barplot

# %%
trios = read.csv2("data/GRtrios_snps_GWAS_enrichment_perm_1000.csv")
trios$fdr=p.adjust(trios$p_value , method = "fdr")
trios$logp_fdr = -log10(trios$fdr)

my_palette = brewer.pal(n = length(unique(trios$Type)), name = "Set3")

# Sort the data frame by Type and then data within Type
trios = trios %>%
  arrange(Type, data)  

ggplot(trios, aes(x = fct_reorder2(data,  data, Type), y = logp_fdr, fill = Type)) +
  geom_bar(stat = "identity", position = position_dodge()) +
  coord_flip() +
  theme_classic() +
  geom_hline(yintercept = -log10(0.1), color = "red")+
  scale_fill_manual(values = my_palette) + xlab("")
# Out:
# plot without title

# %%
sessionInfo()
# Out:
# R version 4.2.1 (2022-06-23)
# Platform: x86_64-apple-darwin17.0 (64-bit)
# Running under: macOS Big Sur ... 10.16
#
# Matrix products: default
# BLAS:   /Library/Frameworks/R.framework/Versions/4.2/Resources/lib/libRblas.0.dylib
# LAPACK: /Library/Frameworks/R.framework/Versions/4.2/Resources/lib/libRlapack.dylib
#
# locale:
# [1] C/UTF-8/C/C/C/C
#
# attached base packages:
# [1] grid      stats     graphics  grDevices utils     datasets  methods
# [8] base
#
# other attached packages:
#  [1] orthologsBioMART_0.1.0 biomaRt_2.52.0         scales_1.2.1
#  [4] sna_2.7-1              statnet.common_4.9.0   network_1.18.1
#  [7] ggnet_0.1.0            kimono_2.0.1.0006      hmlasso_0.0.1
# [10] checkmate_2.2.0        miselect_0.9.0         impute_1.70.0
# [13] mice_3.16.0            lubridate_1.9.2        forcats_1.0.0
# [16] stringr_1.5.0          purrr_1.0.1            readr_2.1.4
# [19] tidyr_1.3.0            tibble_3.2.1           tidyverse_2.0.0
# [22] doSNOW_1.0.20          snow_0.4-4             iterators_1.0.14
# [25] foreach_1.5.2          oem_2.0.11             bigmemory_4.6.1
# [28] dplyr_1.1.2            data.table_1.14.8      igraph_1.5.0
# [31] RColorBrewer_1.1-3     VennDiagram_1.7.3      futile.logger_1.4.3
# [34] openxlsx_4.2.5.2       ggplot2_3.4.3
#
# loaded via a namespace (and not attached):
#   [1] uuid_1.1-0             backports_1.4.1        BiocFileCache_2.4.0
#   [4] repr_1.1.6             splines_4.2.1          GenomeInfoDb_1.32.4
#   [7] digest_0.6.33          htmltools_0.5.5        fansi_1.0.4
#  [10] magrittr_2.0.3         memoise_2.0.1          tzdb_0.4.0
#  [13] Biostrings_2.64.1      timechange_0.2.0       prettyunits_1.1.1
#  [16] colorspace_2.1-0       blob_1.2.4             rappdirs_0.3.3
#  [19] pan_1.8                crayon_1.5.2           RCurl_1.98-1.12
#  [22] jsonlite_1.8.7         bigmemory.sri_0.1.6    lme4_1.1-34
#  [25] survival_3.5-5         glue_1.6.2             gtable_0.3.4
#  [28] zlibbioc_1.42.0        XVector_0.36.0         shape_1.4.6
#  [31] BiocGenerics_0.42.0    jomo_2.7-6             futile.options_1.0.1
#  [34] DBI_1.1.3              Rcpp_1.0.11            progress_1.2.2
#  [37] bit_4.0.5              stats4_4.2.1           glmnet_4.1-7
#  [40] httr_1.4.6             pkgconfig_2.0.3        XML_3.99-0.14
#  [43] farver_2.1.1           nnet_7.3-19            dbplyr_2.3.3
#  [46] utf8_1.2.3             tidyselect_1.2.0       labeling_0.4.3
#  [49] rlang_1.1.1            AnnotationDbi_1.58.0   munsell_0.5.0
#  [52] tools_4.2.1            cachem_1.0.8           cli_3.6.1
#  [55] generics_0.1.3         RSQLite_2.3.1          broom_1.0.5
#  [58] evaluate_0.21          fastmap_1.1.1          bit64_4.0.5
#  [61] zip_2.3.0              KEGGREST_1.36.3        mitml_0.4-5
#  [64] nlme_3.1-162           formatR_1.14           xml2_1.3.5
#  [67] compiler_4.2.1         filelock_1.0.2         curl_5.0.1
#  [70] png_0.1-8              stringi_1.7.12         RSpectra_0.16-1
#  [73] lattice_0.21-8         IRdisplay_1.1          Matrix_1.5-4.1
#  [76] nloptr_2.0.3           vctrs_0.6.3            pillar_1.9.0
#  [79] lifecycle_1.0.3        bitops_1.0-7           R6_2.5.1
#  [82] IRanges_2.30.1         codetools_0.2-19       lambda.r_1.2.4
#  [85] boot_1.3-28.1          MASS_7.3-60            withr_2.5.0
#  [88] S4Vectors_0.34.0       GenomeInfoDbData_1.2.8 intergraph_2.0-3
#  [91] parallel_4.2.1         hms_1.1.3              rpart_4.1.19
#  [94] IRkernel_1.3.2         coda_0.19-4            minqa_1.2.5
#  [97] Cairo_1.6-0            pbdZMQ_0.3-11          Biobase_2.56.0
# [100] base64enc_0.1-3
